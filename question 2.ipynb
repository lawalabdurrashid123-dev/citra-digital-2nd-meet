# %% [markdown]
# <a href="https://colab.research.google.com/github/lawalabdurrashid123-dev/citra-digital-2nd-meet/blob/main/question%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy.ndimage import label

image = cv2.imread('my.jpg')

if image is None:
    print("Image not found. Please put 'input.jpg' in the same folder.")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    sizes = [512, 256, 128, 64]

    plt.figure(figsize=(10,8))
    for i, size in enumerate(sizes):
        resized = cv2.resize(image_rgb, (size, size), interpolation=cv2.INTER_AREA)
        plt.subplot(2,2,i+1)
        plt.imshow(resized)
        plt.title(f"{size}x{size}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()
